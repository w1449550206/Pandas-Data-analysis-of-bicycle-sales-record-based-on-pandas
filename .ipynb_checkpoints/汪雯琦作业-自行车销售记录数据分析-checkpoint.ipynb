# %% [markdown]
# # 思路：
# - 导入数据集；
# - 检查数据基本属性；
# - 修改个别表头、舍弃缺失的不完整数据行；
# - 对时间这一列信息进行特殊处理，舍弃星期的信息，然后将时间这一列数据的格式转为时间格式pd.to_datetime()；
# - “销售数量”、“应收金额”、“实收金额”这三列数据显然不可能有负数，我们要舍弃掉一些异常值的数据行；
# - 对数据按时间升序排序，重置其索引；
# - 计算商品的种类和商品的总销售数量；
# - 计算总销售次数，月份数，月均销售次数；
# - 计算总销售金额，平均每月销售金额，平均每单销售金额；
# - 计算最大和最小日销售金额及对应的日期、最大和最小日销售数量及对应的日期；
# - 画出各个月单独的每日销售金额直方图、每月销售金额直方图、每月销售金额变化直线图、销量前十和最后十名的自行车的直方图。
#
# - 代码实现

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
from pylab import mpl  # 用于画图时显示中文字符

# %%
mpl.rcParams['font.sans-serif'] = ['SimHei']  # 使用matplotlib画图时如果出现中文使用黑体字体
file_data = pd.read_excel("销售记录.xlsx")  # 读取数据文件

# %%
file_data
# Out:
#            订单编号   客户ID              客户名称            客户编号 客户省份  销售代表ID  \
# 0       SO45266  29955  广东29955自行车销售有限公司  10-4020-000018   广东     212
# 1       SO45266  29955  广东29955自行车销售有限公司  10-4020-000018   广东     212
# 2       SO45267  29611  福建29611自行车销售有限公司  10-4020-000271   福建     211
# 3       SO45268  29548  江苏29548自行车销售有限公司  10-4020-000318   江苏     201
# 4       SO45269  29620  福建29620自行车销售有限公司  10-4020-000353   福建     211
# 5       SO45270  29888  江苏29888自行车销售有限公司  10-4020-000206   江苏     201
# 6       SO45270  29888  江苏29888自行车销售有限公司  10-4020-000206   江苏     201
# 7       SO45270  29888  江苏29888自行车销售有限公司  10-4020-000206   江苏     201
# 8       SO45271  29555  湖南29555自行车销售有限公司  10-4020-000162   湖南     210
# 9       SO45272  29539  北京29539自行车销售有限公司  10-4020-000210   北京     205
# 10      SO45273  29717  四川29717自行车销售有限公司  10-4020-000164   四川     214
# 11      SO45274  29818  甘肃29818自行车销售有限公司  10-4020-000697   甘肃     213
# 12      SO45274  29818  甘肃29818自行车销售有限公司  10-4020-000697   甘肃     213
# 13      SO45274  29818  甘肃29818自行车销售有限公司  10-4020-000697   甘肃     213
# 14      SO45275  30011  江苏30011自行车销售有限公司  10-4020-000531   江苏     201
# 15      SO45276  29813  新疆29813自行车销售有限公司  10-4020-000011   新疆     213
# 16      SO45277  29509  新疆29509自行车销售有限公司  10-4020-000558   新疆     213
# 17      SO45277  29509  新疆29509自行车销售有限公司  10-4020-000558   新疆     213
# 18      SO45278  29892  吉林29892自行车销售有限公司  10-4020-000191   吉林     207
# 19      SO45278  29892  吉林29892自行车销售有限公司  10-4020-000191   吉林     207
# 20      SO45279  29988  海南29988自行车销售有限公司  10-4020-000208   海南     209
# 21      SO45279  29988  海南29988自行车销售有限公司  10-4020-000208   海南     209
# 22      SO45280  29946  辽宁29946自行车销售有限公司  10-4020-000102   辽宁     207
# 23      SO45280  29946  辽宁29946自行车销售有限公司  10-4020-000102   辽宁     207
# 24      SO45281  29554  天津29554自行车销售有限公司  10-4020-000198   天津     208
# 25      SO45282  29680  北京29680自行车销售有限公司  10-4020-000389   北京     205
# 26      SO45282  29680  北京29680自行车销售有限公司  10-4020-000389   北京     205
# 27      SO45283  29773  湖南29773自行车销售有限公司  10-4020-000001   湖南     210
# 28      SO45283  29773  湖南29773自行车销售有限公司  10-4020-000001   湖南     210
# 29      SO45284  30074  西藏30074自行车销售有限公司  10-4020-000533   西藏     213
# ...         ...    ...               ...             ...  ...     ...
# 15062  SO458081  29606  重庆29606自行车销售有限公司  10-4020-000344   重庆     214
# 15063  SO458091  29718  西藏29718自行车销售有限公司  10-4020-000161   西藏     213
# 15064  SO458091  29718  西藏29718自行车销售有限公司  10-4020-000161   西藏     213
# 15065  SO458101  29646  广东29646自行车销售有限公司  10-4020-000166   广东     212
# 15066  SO458101  29646  广东29646自行车销售有限公司  10-4020-000166   广东     212
# 15067  SO458111  29570  青海29570自行车销售有限公司  10-4020-000292   青海     213
# 15068  SO458111  29570  青海29570自行车销售有限公司  10-4020-000292   青海     213
# 15069  SO458121  29533  上海29533自行车销售有限公司  10-4020-000431   上海     202
# 15070  SO458121  29533  上海29533自行车销售有限公司  10-4020-000431   上海     202
# 15071  SO458121  29533  上海29533自行车销售有限公司  10-4020-000431   上海     202
# 15072  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15073  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15074  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15075  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15076  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15077  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15078  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15079  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15080  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15081  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15082  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15083  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15084  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15085  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15086  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15087  SO458161  11830  广西11830自行车销售有限公司  10-4030-011830   广西     209
# 15088  SO458171  14801  浙江14801自行车销售有限公司  10-4030-014801   浙江     204
# 15089  SO458181  14868  天津14868自行车销售有限公司  10-4030-014868   天津     208
# 15090  SO458191  20160  浙江20160自行车销售有限公司  10-4030-020160   浙江     204
# 15091  SO458201  25832  上海25832自行车销售有限公司  10-4030-025832   上海     202
#
#             下单日期     预计送货日期     实际送货日期  产品ID     产品名称  数量         单价  \
# 0     2015-01-01 2015-01-13 2015-01-02   743    山地自行车  11  2039.9940
# 1     2015-01-01 2015-01-13 2015-01-06   745  山地自行车车架   3   722.5949
# 2     2015-01-01 2015-01-13 2015-01-03   709    公路自行车   5   874.7940
# 3     2015-01-01 2015-01-13 2015-01-08   709    公路自行车   2   419.4589
# 4     2015-01-01 2015-01-13 2015-01-08   743    山地自行车   1  2024.9940
# 5     2015-01-01 2015-01-13 2015-01-14   709    公路自行车  32  2146.9620
# 6     2015-01-01 2015-01-13 2015-01-12   731       帽子   2     5.1865
# 7     2015-01-01 2015-01-13 2015-01-03   759    长袖运动衫   2    28.8404
# 8     2015-01-01 2015-01-13 2015-01-05   709    公路自行车  11   874.7940
# 9     2015-01-01 2015-01-13 2015-01-08   709    公路自行车   9   419.4589
# 10    2015-01-01 2015-01-13 2015-01-10   743    山地自行车  20  2039.9940
# 11    2015-01-01 2015-01-13 2015-01-12   743    山地自行车  33  2039.9940
# 12    2015-01-01 2015-01-13 2015-01-14   758     运动头盔   1    20.1865
# 13    2015-01-01 2015-01-13 2015-01-15   759    长袖运动衫   1    28.8404
# 14    2015-01-01 2015-01-13 2015-01-14   709    公路自行车  16   874.7940
# 15    2015-01-01 2015-01-13 2015-01-02   743    山地自行车   3  2039.9940
# 16    2015-01-01 2015-01-13 2015-01-11   709    公路自行车  32  2146.9620
# 17    2015-01-01 2015-01-13 2015-01-03   731       帽子   3     5.1865
# 18    2015-01-01 2015-01-13 2015-01-13   709    公路自行车  29  2146.9620
# 19    2015-01-01 2015-01-13 2015-01-09   759    长袖运动衫   1    28.8404
# 20    2015-01-01 2015-01-13 2015-01-08   709    公路自行车   2   419.4589
# 21    2015-01-01 2015-01-13 2015-01-07   711  公路自行车车架   1   183.9382
# 22    2015-01-01 2015-01-13 2015-01-12   709    公路自行车  20  2146.9620
# 23    2015-01-01 2015-01-13 2015-01-03   711  公路自行车车架   2   183.9382
# 24    2015-01-01 2015-01-13 2015-01-08   709    公路自行车   3   874.7940
# 25    2015-01-01 2015-01-13 2015-01-16   743    山地自行车   4  2039.9940
# 26    2015-01-01 2015-01-13 2015-01-10   752  山地自行车袜子   2     5.7000
# 27    2015-01-01 2015-01-13 2015-01-12   709    公路自行车  29  2146.9620
# 28    2015-01-01 2015-01-13 2015-01-11   758     运动头盔   2    20.1865
# 29    2015-01-01 2015-01-13 2015-01-12   709    公路自行车  31  2146.9620
# ...          ...        ...        ...   ...      ...  ..        ...
# 15062 2016-02-29 2016-03-12 2016-03-15   709    公路自行车   8   874.7940
# 15063 2016-02-29 2016-03-12 2016-03-07   709    公路自行车  26  2146.9620
# 15064 2016-02-29 2016-03-12 2016-03-15   711  公路自行车车架   8   356.8980
# 15065 2016-02-29 2016-03-12 2016-03-05   709    公路自行车  34  2146.9620
# 15066 2016-02-29 2016-03-12 2016-03-06   711  公路自行车车架  18   758.0759
# 15067 2016-02-29 2016-03-12 2016-03-01   709    公路自行车   6   874.7940
# 15068 2016-02-29 2016-03-12 2016-03-06   759    长袖运动衫   1    28.8404
# 15069 2016-02-29 2016-03-12 2016-03-12   709    公路自行车  13   874.7940
# 15070 2016-02-29 2016-03-12 2016-03-12   731       帽子   2     5.1865
# 15071 2016-02-29 2016-03-12 2016-03-03   759    长袖运动衫   1    28.8404
# 15072 2016-02-29 2016-03-12 2016-03-14   709    公路自行车  50  2146.9620
# 15073 2016-02-29 2016-03-12 2016-03-08   711  公路自行车车架  13   356.8980
# 15074 2016-02-29 2016-03-12 2016-03-12   731       帽子   7     5.1865
# 15075 2016-02-29 2016-03-12 2016-03-02   758     运动头盔  14    20.1865
# 15076 2016-02-29 2016-03-12 2016-03-01   759    长袖运动衫  15    28.8404
# 15077 2016-02-29 2016-03-12 2016-03-09   731       帽子   1     5.1865
# 15078 2016-02-29 2016-03-12 2016-03-15   743    山地自行车  15  2039.9940
# 15079 2016-02-29 2016-03-12 2016-03-04   745  山地自行车车架   4   722.5949
# 15080 2016-02-29 2016-03-12 2016-03-13   752  山地自行车袜子   7     5.7000
# 15081 2016-02-29 2016-03-12 2016-03-14   731       帽子   3     5.1865
# 15082 2016-02-29 2016-03-12 2016-03-05   743    山地自行车  15  2039.9940
# 15083 2016-02-29 2016-03-12 2016-03-13   745  山地自行车车架   2   714.7043
# 15084 2016-02-29 2016-03-12 2016-03-09   752  山地自行车袜子   6     5.7000
# 15085 2016-02-29 2016-03-12 2016-03-03   758     运动头盔   6    20.1865
# 15086 2016-02-29 2016-03-12 2016-03-09   759    长袖运动衫   7    28.8404
# 15087 2016-02-29 2016-03-12 2016-03-14   709    公路自行车   1  3578.2700
# 15088 2016-02-29 2016-03-12 2016-03-06   709    公路自行车   1  3578.2700
# 15089 2016-02-29 2016-03-12 2016-03-10   709    公路自行车   1   699.0982
# 15090 2016-02-29 2016-03-12 2016-03-06   709    公路自行车   1  3578.2700
# 15091 2016-02-29 2016-03-12 2016-03-04   709    公路自行车   1   699.0982
#
#                 金额
# 0       22439.9340
# 1        2167.7847
# 2        4373.9700
# 3         838.9178
# 4        2024.9940
# 5       68702.7840
# 6          10.3730
# 7          57.6808
# 8        9622.7340
# 9        3775.1301
# 10      40799.8800
# 11      67319.8020
# 12         20.1865
# 13         28.8404
# 14      13996.7040
# 15       6119.9820
# 16      68702.7840
# 17         15.5595
# 18      62261.8980
# 19         28.8404
# 20        838.9178
# 21        183.9382
# 22      42939.2400
# 23        367.8764
# 24       2624.3820
# 25       8159.9760
# 26         11.4000
# 27      62261.8980
# 28         40.3730
# 29      66555.8220
# ...            ...
# 15062    6998.3520
# 15063   55821.0120
# 15064    2855.1840
# 15065   72996.7080
# 15066   13645.3662
# 15067    5248.7640
# 15068      28.8404
# 15069   11372.3220
# 15070      10.3730
# 15071      28.8404
# 15072  107348.1000
# 15073    4639.6740
# 15074      36.3055
# 15075     282.6110
# 15076     432.6060
# 15077       5.1865
# 15078   30599.9100
# 15079    2890.3796
# 15080      39.9000
# 15081      15.5595
# 15082   30599.9100
# 15083    1429.4086
# 15084      34.2000
# 15085     121.1190
# 15086     201.8828
# 15087    3578.2700
# 15088    3578.2700
# 15089     699.0982
# 15090    3578.2700
# 15091     699.0982
#
# [15092 rows x 14 columns]

# %%
# 获取文件名
def get_file_name(fl_data):
   # items()函数以列表返回可遍历的(键, 值)元组数组
   # globals()是一个字典，存储了所有的全局变量的名字和对应的变量的值
   # 在这里我们通过判断输入的变量的值与globals()中存储的变量的值是否相等，相等就认为我们输入的变量就是这个globals()中存储的变量
   # 这样我们就返回这个globals()中存储的变量的变量名，即key
   for var_name, value in globals().items():
      if value is fl_data:
         return var_name

# %%
# 显示读入的文件数据的一些基本属性
def show_data_basic_description(fl_data):
   describe_label_shape = get_file_name(file_data) + "文件的shape大小："
   print(describe_label_shape, file_data.shape)
   describe_label_index = get_file_name(file_data) + "文件的索引开头和末尾："
   print(describe_label_index, file_data.index)
   describe_label_table_head = get_file_name(file_data) + "文件的表头项："
   print(describe_label_table_head, file_data.columns)
   describe_label_top_five_line = get_file_name(file_data) + "文件的内容：\n"
   print(describe_label_top_five_line, file_data.head())
   describe_label_data_type = get_file_name(file_data) + "文件的各项的数据类型：\n"
   print(describe_label_data_type, file_data.dtypes)

# %%
print("文件预处理前的各项属性：")
show_data_basic_description(file_data)
# 其中一个列的表头重命名一下
file_data.rename(columns={"下单日期": "销售时间"}, inplace=True)
# Out:
# 文件预处理前的各项属性：
# _文件的shape大小： (15092, 14)
# _文件的索引开头和末尾： RangeIndex(start=0, stop=15092, step=1)
# _文件的表头项： Index(['订单编号', '客户ID', '客户名称', '客户编号', '客户省份', '销售代表ID', '下单日期', '预计送货日期',
#        '实际送货日期', '产品ID', '产品名称', '数量', '单价', '金额'],
#       dtype='object')
# _文件的内容：
#        订单编号   客户ID              客户名称            客户编号 客户省份  销售代表ID       下单日期  \
# 0  SO45266  29955  广东29955自行车销售有限公司  10-4020-000018   广东     212 2015-01-01
# 1  SO45266  29955  广东29955自行车销售有限公司  10-4020-000018   广东     212 2015-01-01
# 2  SO45267  29611  福建29611自行车销售有限公司  10-4020-000271   福建     211 2015-01-01
# 3  SO45268  29548  江苏29548自行车销售有限公司  10-4020-000318   江苏     201 2015-01-01
# 4  SO45269  29620  福建29620自行车销售有限公司  10-4020-000353   福建     211 2015-01-01
#
#       预计送货日期     实际送货日期  产品ID     产品名称  数量         单价          金额
# 0 2015-01-13 2015-01-02   743    山地自行车  11  2039.9940  22439.9340
# 1 2015-01-13 2015-01-06   745  山地自行车车架   3   722.5949   2167.7847
# 2 2015-01-13 2015-01-03   709    公路自行车   5   874.7940   4373.9700
# 3 2015-01-13 2015-01-08   709    公路自行车   2   419.4589    838.9178
# 4 2015-01-13 2015-01-08   743    山地自行车   1  2024.9940   2024.9940
# _文件的各项的数据类型：
#  订单编号              object
# 客户ID               int64
# 客户名称              object
# 客户编号              object
# 客户省份              object
# 销售代表ID             int64
# 下单日期      datetime64[ns]
# 预计送货日期    datetime64[ns]
# 实际送货日期    datetime64[ns]
# 产品ID               int64
# 产品名称              object
# 数量                 int64
# 单价               float64
# 金额               float64
# dtype: object

# %%
# 删除所有有缺失数据的行
file_data = file_data.dropna(subset=['订单编号', '客户ID', '客户名称', '客户编号', '客户省份', '销售代表ID', '销售时间', '预计送货日期', '实际送货日期', '产品ID', '产品名称', '数量', '单价', '金额'], how="any")
file_data
# Out:
#            订单编号   客户ID              客户名称            客户编号 客户省份  销售代表ID  \
# 0       SO45266  29955  广东29955自行车销售有限公司  10-4020-000018   广东     212
# 1       SO45266  29955  广东29955自行车销售有限公司  10-4020-000018   广东     212
# 2       SO45267  29611  福建29611自行车销售有限公司  10-4020-000271   福建     211
# 3       SO45268  29548  江苏29548自行车销售有限公司  10-4020-000318   江苏     201
# 4       SO45269  29620  福建29620自行车销售有限公司  10-4020-000353   福建     211
# 5       SO45270  29888  江苏29888自行车销售有限公司  10-4020-000206   江苏     201
# 6       SO45270  29888  江苏29888自行车销售有限公司  10-4020-000206   江苏     201
# 7       SO45270  29888  江苏29888自行车销售有限公司  10-4020-000206   江苏     201
# 8       SO45271  29555  湖南29555自行车销售有限公司  10-4020-000162   湖南     210
# 9       SO45272  29539  北京29539自行车销售有限公司  10-4020-000210   北京     205
# 10      SO45273  29717  四川29717自行车销售有限公司  10-4020-000164   四川     214
# 11      SO45274  29818  甘肃29818自行车销售有限公司  10-4020-000697   甘肃     213
# 12      SO45274  29818  甘肃29818自行车销售有限公司  10-4020-000697   甘肃     213
# 13      SO45274  29818  甘肃29818自行车销售有限公司  10-4020-000697   甘肃     213
# 14      SO45275  30011  江苏30011自行车销售有限公司  10-4020-000531   江苏     201
# 15      SO45276  29813  新疆29813自行车销售有限公司  10-4020-000011   新疆     213
# 16      SO45277  29509  新疆29509自行车销售有限公司  10-4020-000558   新疆     213
# 17      SO45277  29509  新疆29509自行车销售有限公司  10-4020-000558   新疆     213
# 18      SO45278  29892  吉林29892自行车销售有限公司  10-4020-000191   吉林     207
# 19      SO45278  29892  吉林29892自行车销售有限公司  10-4020-000191   吉林     207
# 20      SO45279  29988  海南29988自行车销售有限公司  10-4020-000208   海南     209
# 21      SO45279  29988  海南29988自行车销售有限公司  10-4020-000208   海南     209
# 22      SO45280  29946  辽宁29946自行车销售有限公司  10-4020-000102   辽宁     207
# 23      SO45280  29946  辽宁29946自行车销售有限公司  10-4020-000102   辽宁     207
# 24      SO45281  29554  天津29554自行车销售有限公司  10-4020-000198   天津     208
# 25      SO45282  29680  北京29680自行车销售有限公司  10-4020-000389   北京     205
# 26      SO45282  29680  北京29680自行车销售有限公司  10-4020-000389   北京     205
# 27      SO45283  29773  湖南29773自行车销售有限公司  10-4020-000001   湖南     210
# 28      SO45283  29773  湖南29773自行车销售有限公司  10-4020-000001   湖南     210
# 29      SO45284  30074  西藏30074自行车销售有限公司  10-4020-000533   西藏     213
# ...         ...    ...               ...             ...  ...     ...
# 15062  SO458081  29606  重庆29606自行车销售有限公司  10-4020-000344   重庆     214
# 15063  SO458091  29718  西藏29718自行车销售有限公司  10-4020-000161   西藏     213
# 15064  SO458091  29718  西藏29718自行车销售有限公司  10-4020-000161   西藏     213
# 15065  SO458101  29646  广东29646自行车销售有限公司  10-4020-000166   广东     212
# 15066  SO458101  29646  广东29646自行车销售有限公司  10-4020-000166   广东     212
# 15067  SO458111  29570  青海29570自行车销售有限公司  10-4020-000292   青海     213
# 15068  SO458111  29570  青海29570自行车销售有限公司  10-4020-000292   青海     213
# 15069  SO458121  29533  上海29533自行车销售有限公司  10-4020-000431   上海     202
# 15070  SO458121  29533  上海29533自行车销售有限公司  10-4020-000431   上海     202
# 15071  SO458121  29533  上海29533自行车销售有限公司  10-4020-000431   上海     202
# 15072  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15073  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15074  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15075  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15076  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15077  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15078  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15079  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15080  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15081  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15082  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15083  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15084  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15085  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15086  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15087  SO458161  11830  广西11830自行车销售有限公司  10-4030-011830   广西     209
# 15088  SO458171  14801  浙江14801自行车销售有限公司  10-4030-014801   浙江     204
# 15089  SO458181  14868  天津14868自行车销售有限公司  10-4030-014868   天津     208
# 15090  SO458191  20160  浙江20160自行车销售有限公司  10-4030-020160   浙江     204
# 15091  SO458201  25832  上海25832自行车销售有限公司  10-4030-025832   上海     202
#
#             销售时间     预计送货日期     实际送货日期  产品ID     产品名称  数量         单价  \
# 0     2015-01-01 2015-01-13 2015-01-02   743    山地自行车  11  2039.9940
# 1     2015-01-01 2015-01-13 2015-01-06   745  山地自行车车架   3   722.5949
# 2     2015-01-01 2015-01-13 2015-01-03   709    公路自行车   5   874.7940
# 3     2015-01-01 2015-01-13 2015-01-08   709    公路自行车   2   419.4589
# 4     2015-01-01 2015-01-13 2015-01-08   743    山地自行车   1  2024.9940
# 5     2015-01-01 2015-01-13 2015-01-14   709    公路自行车  32  2146.9620
# 6     2015-01-01 2015-01-13 2015-01-12   731       帽子   2     5.1865
# 7     2015-01-01 2015-01-13 2015-01-03   759    长袖运动衫   2    28.8404
# 8     2015-01-01 2015-01-13 2015-01-05   709    公路自行车  11   874.7940
# 9     2015-01-01 2015-01-13 2015-01-08   709    公路自行车   9   419.4589
# 10    2015-01-01 2015-01-13 2015-01-10   743    山地自行车  20  2039.9940
# 11    2015-01-01 2015-01-13 2015-01-12   743    山地自行车  33  2039.9940
# 12    2015-01-01 2015-01-13 2015-01-14   758     运动头盔   1    20.1865
# 13    2015-01-01 2015-01-13 2015-01-15   759    长袖运动衫   1    28.8404
# 14    2015-01-01 2015-01-13 2015-01-14   709    公路自行车  16   874.7940
# 15    2015-01-01 2015-01-13 2015-01-02   743    山地自行车   3  2039.9940
# 16    2015-01-01 2015-01-13 2015-01-11   709    公路自行车  32  2146.9620
# 17    2015-01-01 2015-01-13 2015-01-03   731       帽子   3     5.1865
# 18    2015-01-01 2015-01-13 2015-01-13   709    公路自行车  29  2146.9620
# 19    2015-01-01 2015-01-13 2015-01-09   759    长袖运动衫   1    28.8404
# 20    2015-01-01 2015-01-13 2015-01-08   709    公路自行车   2   419.4589
# 21    2015-01-01 2015-01-13 2015-01-07   711  公路自行车车架   1   183.9382
# 22    2015-01-01 2015-01-13 2015-01-12   709    公路自行车  20  2146.9620
# 23    2015-01-01 2015-01-13 2015-01-03   711  公路自行车车架   2   183.9382
# 24    2015-01-01 2015-01-13 2015-01-08   709    公路自行车   3   874.7940
# 25    2015-01-01 2015-01-13 2015-01-16   743    山地自行车   4  2039.9940
# 26    2015-01-01 2015-01-13 2015-01-10   752  山地自行车袜子   2     5.7000
# 27    2015-01-01 2015-01-13 2015-01-12   709    公路自行车  29  2146.9620
# 28    2015-01-01 2015-01-13 2015-01-11   758     运动头盔   2    20.1865
# 29    2015-01-01 2015-01-13 2015-01-12   709    公路自行车  31  2146.9620
# ...          ...        ...        ...   ...      ...  ..        ...
# 15062 2016-02-29 2016-03-12 2016-03-15   709    公路自行车   8   874.7940
# 15063 2016-02-29 2016-03-12 2016-03-07   709    公路自行车  26  2146.9620
# 15064 2016-02-29 2016-03-12 2016-03-15   711  公路自行车车架   8   356.8980
# 15065 2016-02-29 2016-03-12 2016-03-05   709    公路自行车  34  2146.9620
# 15066 2016-02-29 2016-03-12 2016-03-06   711  公路自行车车架  18   758.0759
# 15067 2016-02-29 2016-03-12 2016-03-01   709    公路自行车   6   874.7940
# 15068 2016-02-29 2016-03-12 2016-03-06   759    长袖运动衫   1    28.8404
# 15069 2016-02-29 2016-03-12 2016-03-12   709    公路自行车  13   874.7940
# 15070 2016-02-29 2016-03-12 2016-03-12   731       帽子   2     5.1865
# 15071 2016-02-29 2016-03-12 2016-03-03   759    长袖运动衫   1    28.8404
# 15072 2016-02-29 2016-03-12 2016-03-14   709    公路自行车  50  2146.9620
# 15073 2016-02-29 2016-03-12 2016-03-08   711  公路自行车车架  13   356.8980
# 15074 2016-02-29 2016-03-12 2016-03-12   731       帽子   7     5.1865
# 15075 2016-02-29 2016-03-12 2016-03-02   758     运动头盔  14    20.1865
# 15076 2016-02-29 2016-03-12 2016-03-01   759    长袖运动衫  15    28.8404
# 15077 2016-02-29 2016-03-12 2016-03-09   731       帽子   1     5.1865
# 15078 2016-02-29 2016-03-12 2016-03-15   743    山地自行车  15  2039.9940
# 15079 2016-02-29 2016-03-12 2016-03-04   745  山地自行车车架   4   722.5949
# 15080 2016-02-29 2016-03-12 2016-03-13   752  山地自行车袜子   7     5.7000
# 15081 2016-02-29 2016-03-12 2016-03-14   731       帽子   3     5.1865
# 15082 2016-02-29 2016-03-12 2016-03-05   743    山地自行车  15  2039.9940
# 15083 2016-02-29 2016-03-12 2016-03-13   745  山地自行车车架   2   714.7043
# 15084 2016-02-29 2016-03-12 2016-03-09   752  山地自行车袜子   6     5.7000
# 15085 2016-02-29 2016-03-12 2016-03-03   758     运动头盔   6    20.1865
# 15086 2016-02-29 2016-03-12 2016-03-09   759    长袖运动衫   7    28.8404
# 15087 2016-02-29 2016-03-12 2016-03-14   709    公路自行车   1  3578.2700
# 15088 2016-02-29 2016-03-12 2016-03-06   709    公路自行车   1  3578.2700
# 15089 2016-02-29 2016-03-12 2016-03-10   709    公路自行车   1   699.0982
# 15090 2016-02-29 2016-03-12 2016-03-06   709    公路自行车   1  3578.2700
# 15091 2016-02-29 2016-03-12 2016-03-04   709    公路自行车   1   699.0982
#
#                 金额
# 0       22439.9340
# 1        2167.7847
# 2        4373.9700
# 3         838.9178
# 4        2024.9940
# 5       68702.7840
# 6          10.3730
# 7          57.6808
# 8        9622.7340
# 9        3775.1301
# 10      40799.8800
# 11      67319.8020
# 12         20.1865
# 13         28.8404
# 14      13996.7040
# 15       6119.9820
# 16      68702.7840
# 17         15.5595
# 18      62261.8980
# 19         28.8404
# 20        838.9178
# 21        183.9382
# 22      42939.2400
# 23        367.8764
# 24       2624.3820
# 25       8159.9760
# 26         11.4000
# 27      62261.8980
# 28         40.3730
# 29      66555.8220
# ...            ...
# 15062    6998.3520
# 15063   55821.0120
# 15064    2855.1840
# 15065   72996.7080
# 15066   13645.3662
# 15067    5248.7640
# 15068      28.8404
# 15069   11372.3220
# 15070      10.3730
# 15071      28.8404
# 15072  107348.1000
# 15073    4639.6740
# 15074      36.3055
# 15075     282.6110
# 15076     432.6060
# 15077       5.1865
# 15078   30599.9100
# 15079    2890.3796
# 15080      39.9000
# 15081      15.5595
# 15082   30599.9100
# 15083    1429.4086
# 15084      34.2000
# 15085     121.1190
# 15086     201.8828
# 15087    3578.2700
# 15088    3578.2700
# 15089     699.0982
# 15090    3578.2700
# 15091     699.0982
#
# [15092 rows x 14 columns]

# %%
# 删除无效时间的数据,没有
file_data = file_data.dropna(subset=["销售时间"], how="any")
file_data
# Out:
#            订单编号   客户ID              客户名称            客户编号 客户省份  销售代表ID  \
# 0       SO45266  29955  广东29955自行车销售有限公司  10-4020-000018   广东     212
# 1       SO45266  29955  广东29955自行车销售有限公司  10-4020-000018   广东     212
# 2       SO45267  29611  福建29611自行车销售有限公司  10-4020-000271   福建     211
# 3       SO45268  29548  江苏29548自行车销售有限公司  10-4020-000318   江苏     201
# 4       SO45269  29620  福建29620自行车销售有限公司  10-4020-000353   福建     211
# 5       SO45270  29888  江苏29888自行车销售有限公司  10-4020-000206   江苏     201
# 6       SO45270  29888  江苏29888自行车销售有限公司  10-4020-000206   江苏     201
# 7       SO45270  29888  江苏29888自行车销售有限公司  10-4020-000206   江苏     201
# 8       SO45271  29555  湖南29555自行车销售有限公司  10-4020-000162   湖南     210
# 9       SO45272  29539  北京29539自行车销售有限公司  10-4020-000210   北京     205
# 10      SO45273  29717  四川29717自行车销售有限公司  10-4020-000164   四川     214
# 11      SO45274  29818  甘肃29818自行车销售有限公司  10-4020-000697   甘肃     213
# 12      SO45274  29818  甘肃29818自行车销售有限公司  10-4020-000697   甘肃     213
# 13      SO45274  29818  甘肃29818自行车销售有限公司  10-4020-000697   甘肃     213
# 14      SO45275  30011  江苏30011自行车销售有限公司  10-4020-000531   江苏     201
# 15      SO45276  29813  新疆29813自行车销售有限公司  10-4020-000011   新疆     213
# 16      SO45277  29509  新疆29509自行车销售有限公司  10-4020-000558   新疆     213
# 17      SO45277  29509  新疆29509自行车销售有限公司  10-4020-000558   新疆     213
# 18      SO45278  29892  吉林29892自行车销售有限公司  10-4020-000191   吉林     207
# 19      SO45278  29892  吉林29892自行车销售有限公司  10-4020-000191   吉林     207
# 20      SO45279  29988  海南29988自行车销售有限公司  10-4020-000208   海南     209
# 21      SO45279  29988  海南29988自行车销售有限公司  10-4020-000208   海南     209
# 22      SO45280  29946  辽宁29946自行车销售有限公司  10-4020-000102   辽宁     207
# 23      SO45280  29946  辽宁29946自行车销售有限公司  10-4020-000102   辽宁     207
# 24      SO45281  29554  天津29554自行车销售有限公司  10-4020-000198   天津     208
# 25      SO45282  29680  北京29680自行车销售有限公司  10-4020-000389   北京     205
# 26      SO45282  29680  北京29680自行车销售有限公司  10-4020-000389   北京     205
# 27      SO45283  29773  湖南29773自行车销售有限公司  10-4020-000001   湖南     210
# 28      SO45283  29773  湖南29773自行车销售有限公司  10-4020-000001   湖南     210
# 29      SO45284  30074  西藏30074自行车销售有限公司  10-4020-000533   西藏     213
# ...         ...    ...               ...             ...  ...     ...
# 15062  SO458081  29606  重庆29606自行车销售有限公司  10-4020-000344   重庆     214
# 15063  SO458091  29718  西藏29718自行车销售有限公司  10-4020-000161   西藏     213
# 15064  SO458091  29718  西藏29718自行车销售有限公司  10-4020-000161   西藏     213
# 15065  SO458101  29646  广东29646自行车销售有限公司  10-4020-000166   广东     212
# 15066  SO458101  29646  广东29646自行车销售有限公司  10-4020-000166   广东     212
# 15067  SO458111  29570  青海29570自行车销售有限公司  10-4020-000292   青海     213
# 15068  SO458111  29570  青海29570自行车销售有限公司  10-4020-000292   青海     213
# 15069  SO458121  29533  上海29533自行车销售有限公司  10-4020-000431   上海     202
# 15070  SO458121  29533  上海29533自行车销售有限公司  10-4020-000431   上海     202
# 15071  SO458121  29533  上海29533自行车销售有限公司  10-4020-000431   上海     202
# 15072  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15073  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15074  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15075  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15076  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15077  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15078  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15079  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15080  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15081  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15082  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15083  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15084  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15085  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15086  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15087  SO458161  11830  广西11830自行车销售有限公司  10-4030-011830   广西     209
# 15088  SO458171  14801  浙江14801自行车销售有限公司  10-4030-014801   浙江     204
# 15089  SO458181  14868  天津14868自行车销售有限公司  10-4030-014868   天津     208
# 15090  SO458191  20160  浙江20160自行车销售有限公司  10-4030-020160   浙江     204
# 15091  SO458201  25832  上海25832自行车销售有限公司  10-4030-025832   上海     202
#
#             销售时间     预计送货日期     实际送货日期  产品ID     产品名称  数量         单价  \
# 0     2015-01-01 2015-01-13 2015-01-02   743    山地自行车  11  2039.9940
# 1     2015-01-01 2015-01-13 2015-01-06   745  山地自行车车架   3   722.5949
# 2     2015-01-01 2015-01-13 2015-01-03   709    公路自行车   5   874.7940
# 3     2015-01-01 2015-01-13 2015-01-08   709    公路自行车   2   419.4589
# 4     2015-01-01 2015-01-13 2015-01-08   743    山地自行车   1  2024.9940
# 5     2015-01-01 2015-01-13 2015-01-14   709    公路自行车  32  2146.9620
# 6     2015-01-01 2015-01-13 2015-01-12   731       帽子   2     5.1865
# 7     2015-01-01 2015-01-13 2015-01-03   759    长袖运动衫   2    28.8404
# 8     2015-01-01 2015-01-13 2015-01-05   709    公路自行车  11   874.7940
# 9     2015-01-01 2015-01-13 2015-01-08   709    公路自行车   9   419.4589
# 10    2015-01-01 2015-01-13 2015-01-10   743    山地自行车  20  2039.9940
# 11    2015-01-01 2015-01-13 2015-01-12   743    山地自行车  33  2039.9940
# 12    2015-01-01 2015-01-13 2015-01-14   758     运动头盔   1    20.1865
# 13    2015-01-01 2015-01-13 2015-01-15   759    长袖运动衫   1    28.8404
# 14    2015-01-01 2015-01-13 2015-01-14   709    公路自行车  16   874.7940
# 15    2015-01-01 2015-01-13 2015-01-02   743    山地自行车   3  2039.9940
# 16    2015-01-01 2015-01-13 2015-01-11   709    公路自行车  32  2146.9620
# 17    2015-01-01 2015-01-13 2015-01-03   731       帽子   3     5.1865
# 18    2015-01-01 2015-01-13 2015-01-13   709    公路自行车  29  2146.9620
# 19    2015-01-01 2015-01-13 2015-01-09   759    长袖运动衫   1    28.8404
# 20    2015-01-01 2015-01-13 2015-01-08   709    公路自行车   2   419.4589
# 21    2015-01-01 2015-01-13 2015-01-07   711  公路自行车车架   1   183.9382
# 22    2015-01-01 2015-01-13 2015-01-12   709    公路自行车  20  2146.9620
# 23    2015-01-01 2015-01-13 2015-01-03   711  公路自行车车架   2   183.9382
# 24    2015-01-01 2015-01-13 2015-01-08   709    公路自行车   3   874.7940
# 25    2015-01-01 2015-01-13 2015-01-16   743    山地自行车   4  2039.9940
# 26    2015-01-01 2015-01-13 2015-01-10   752  山地自行车袜子   2     5.7000
# 27    2015-01-01 2015-01-13 2015-01-12   709    公路自行车  29  2146.9620
# 28    2015-01-01 2015-01-13 2015-01-11   758     运动头盔   2    20.1865
# 29    2015-01-01 2015-01-13 2015-01-12   709    公路自行车  31  2146.9620
# ...          ...        ...        ...   ...      ...  ..        ...
# 15062 2016-02-29 2016-03-12 2016-03-15   709    公路自行车   8   874.7940
# 15063 2016-02-29 2016-03-12 2016-03-07   709    公路自行车  26  2146.9620
# 15064 2016-02-29 2016-03-12 2016-03-15   711  公路自行车车架   8   356.8980
# 15065 2016-02-29 2016-03-12 2016-03-05   709    公路自行车  34  2146.9620
# 15066 2016-02-29 2016-03-12 2016-03-06   711  公路自行车车架  18   758.0759
# 15067 2016-02-29 2016-03-12 2016-03-01   709    公路自行车   6   874.7940
# 15068 2016-02-29 2016-03-12 2016-03-06   759    长袖运动衫   1    28.8404
# 15069 2016-02-29 2016-03-12 2016-03-12   709    公路自行车  13   874.7940
# 15070 2016-02-29 2016-03-12 2016-03-12   731       帽子   2     5.1865
# 15071 2016-02-29 2016-03-12 2016-03-03   759    长袖运动衫   1    28.8404
# 15072 2016-02-29 2016-03-12 2016-03-14   709    公路自行车  50  2146.9620
# 15073 2016-02-29 2016-03-12 2016-03-08   711  公路自行车车架  13   356.8980
# 15074 2016-02-29 2016-03-12 2016-03-12   731       帽子   7     5.1865
# 15075 2016-02-29 2016-03-12 2016-03-02   758     运动头盔  14    20.1865
# 15076 2016-02-29 2016-03-12 2016-03-01   759    长袖运动衫  15    28.8404
# 15077 2016-02-29 2016-03-12 2016-03-09   731       帽子   1     5.1865
# 15078 2016-02-29 2016-03-12 2016-03-15   743    山地自行车  15  2039.9940
# 15079 2016-02-29 2016-03-12 2016-03-04   745  山地自行车车架   4   722.5949
# 15080 2016-02-29 2016-03-12 2016-03-13   752  山地自行车袜子   7     5.7000
# 15081 2016-02-29 2016-03-12 2016-03-14   731       帽子   3     5.1865
# 15082 2016-02-29 2016-03-12 2016-03-05   743    山地自行车  15  2039.9940
# 15083 2016-02-29 2016-03-12 2016-03-13   745  山地自行车车架   2   714.7043
# 15084 2016-02-29 2016-03-12 2016-03-09   752  山地自行车袜子   6     5.7000
# 15085 2016-02-29 2016-03-12 2016-03-03   758     运动头盔   6    20.1865
# 15086 2016-02-29 2016-03-12 2016-03-09   759    长袖运动衫   7    28.8404
# 15087 2016-02-29 2016-03-12 2016-03-14   709    公路自行车   1  3578.2700
# 15088 2016-02-29 2016-03-12 2016-03-06   709    公路自行车   1  3578.2700
# 15089 2016-02-29 2016-03-12 2016-03-10   709    公路自行车   1   699.0982
# 15090 2016-02-29 2016-03-12 2016-03-06   709    公路自行车   1  3578.2700
# 15091 2016-02-29 2016-03-12 2016-03-04   709    公路自行车   1   699.0982
#
#                 金额
# 0       22439.9340
# 1        2167.7847
# 2        4373.9700
# 3         838.9178
# 4        2024.9940
# 5       68702.7840
# 6          10.3730
# 7          57.6808
# 8        9622.7340
# 9        3775.1301
# 10      40799.8800
# 11      67319.8020
# 12         20.1865
# 13         28.8404
# 14      13996.7040
# 15       6119.9820
# 16      68702.7840
# 17         15.5595
# 18      62261.8980
# 19         28.8404
# 20        838.9178
# 21        183.9382
# 22      42939.2400
# 23        367.8764
# 24       2624.3820
# 25       8159.9760
# 26         11.4000
# 27      62261.8980
# 28         40.3730
# 29      66555.8220
# ...            ...
# 15062    6998.3520
# 15063   55821.0120
# 15064    2855.1840
# 15065   72996.7080
# 15066   13645.3662
# 15067    5248.7640
# 15068      28.8404
# 15069   11372.3220
# 15070      10.3730
# 15071      28.8404
# 15072  107348.1000
# 15073    4639.6740
# 15074      36.3055
# 15075     282.6110
# 15076     432.6060
# 15077       5.1865
# 15078   30599.9100
# 15079    2890.3796
# 15080      39.9000
# 15081      15.5595
# 15082   30599.9100
# 15083    1429.4086
# 15084      34.2000
# 15085     121.1190
# 15086     201.8828
# 15087    3578.2700
# 15088    3578.2700
# 15089     699.0982
# 15090    3578.2700
# 15091     699.0982
#
# [15092 rows x 14 columns]

# %%
# 处理异常值：“数量”、“单价”、“金额”这三列数据显然不可能有负数，因此要去掉不合理的数据
pop = file_data.loc[:, "金额"] > 0
file_data = file_data.loc[pop, :]
file_data
# Out:
#            订单编号   客户ID              客户名称            客户编号 客户省份  销售代表ID  \
# 0       SO45266  29955  广东29955自行车销售有限公司  10-4020-000018   广东     212
# 1       SO45266  29955  广东29955自行车销售有限公司  10-4020-000018   广东     212
# 2       SO45267  29611  福建29611自行车销售有限公司  10-4020-000271   福建     211
# 3       SO45268  29548  江苏29548自行车销售有限公司  10-4020-000318   江苏     201
# 4       SO45269  29620  福建29620自行车销售有限公司  10-4020-000353   福建     211
# 5       SO45270  29888  江苏29888自行车销售有限公司  10-4020-000206   江苏     201
# 6       SO45270  29888  江苏29888自行车销售有限公司  10-4020-000206   江苏     201
# 7       SO45270  29888  江苏29888自行车销售有限公司  10-4020-000206   江苏     201
# 8       SO45271  29555  湖南29555自行车销售有限公司  10-4020-000162   湖南     210
# 9       SO45272  29539  北京29539自行车销售有限公司  10-4020-000210   北京     205
# 10      SO45273  29717  四川29717自行车销售有限公司  10-4020-000164   四川     214
# 11      SO45274  29818  甘肃29818自行车销售有限公司  10-4020-000697   甘肃     213
# 12      SO45274  29818  甘肃29818自行车销售有限公司  10-4020-000697   甘肃     213
# 13      SO45274  29818  甘肃29818自行车销售有限公司  10-4020-000697   甘肃     213
# 14      SO45275  30011  江苏30011自行车销售有限公司  10-4020-000531   江苏     201
# 15      SO45276  29813  新疆29813自行车销售有限公司  10-4020-000011   新疆     213
# 16      SO45277  29509  新疆29509自行车销售有限公司  10-4020-000558   新疆     213
# 17      SO45277  29509  新疆29509自行车销售有限公司  10-4020-000558   新疆     213
# 18      SO45278  29892  吉林29892自行车销售有限公司  10-4020-000191   吉林     207
# 19      SO45278  29892  吉林29892自行车销售有限公司  10-4020-000191   吉林     207
# 20      SO45279  29988  海南29988自行车销售有限公司  10-4020-000208   海南     209
# 21      SO45279  29988  海南29988自行车销售有限公司  10-4020-000208   海南     209
# 22      SO45280  29946  辽宁29946自行车销售有限公司  10-4020-000102   辽宁     207
# 23      SO45280  29946  辽宁29946自行车销售有限公司  10-4020-000102   辽宁     207
# 24      SO45281  29554  天津29554自行车销售有限公司  10-4020-000198   天津     208
# 25      SO45282  29680  北京29680自行车销售有限公司  10-4020-000389   北京     205
# 26      SO45282  29680  北京29680自行车销售有限公司  10-4020-000389   北京     205
# 27      SO45283  29773  湖南29773自行车销售有限公司  10-4020-000001   湖南     210
# 28      SO45283  29773  湖南29773自行车销售有限公司  10-4020-000001   湖南     210
# 29      SO45284  30074  西藏30074自行车销售有限公司  10-4020-000533   西藏     213
# ...         ...    ...               ...             ...  ...     ...
# 15062  SO458081  29606  重庆29606自行车销售有限公司  10-4020-000344   重庆     214
# 15063  SO458091  29718  西藏29718自行车销售有限公司  10-4020-000161   西藏     213
# 15064  SO458091  29718  西藏29718自行车销售有限公司  10-4020-000161   西藏     213
# 15065  SO458101  29646  广东29646自行车销售有限公司  10-4020-000166   广东     212
# 15066  SO458101  29646  广东29646自行车销售有限公司  10-4020-000166   广东     212
# 15067  SO458111  29570  青海29570自行车销售有限公司  10-4020-000292   青海     213
# 15068  SO458111  29570  青海29570自行车销售有限公司  10-4020-000292   青海     213
# 15069  SO458121  29533  上海29533自行车销售有限公司  10-4020-000431   上海     202
# 15070  SO458121  29533  上海29533自行车销售有限公司  10-4020-000431   上海     202
# 15071  SO458121  29533  上海29533自行车销售有限公司  10-4020-000431   上海     202
# 15072  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15073  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15074  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15075  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15076  SO458131  29992  上海29992自行车销售有限公司  10-4020-000221   上海     202
# 15077  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15078  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15079  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15080  SO458141  29491  甘肃29491自行车销售有限公司  10-4020-000485   甘肃     213
# 15081  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15082  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15083  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15084  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15085  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15086  SO458151  29549  海南29549自行车销售有限公司  10-4020-000315   海南     209
# 15087  SO458161  11830  广西11830自行车销售有限公司  10-4030-011830   广西     209
# 15088  SO458171  14801  浙江14801自行车销售有限公司  10-4030-014801   浙江     204
# 15089  SO458181  14868  天津14868自行车销售有限公司  10-4030-014868   天津     208
# 15090  SO458191  20160  浙江20160自行车销售有限公司  10-4030-020160   浙江     204
# 15091  SO458201  25832  上海25832自行车销售有限公司  10-4030-025832   上海     202
#
#             销售时间     预计送货日期     实际送货日期  产品ID     产品名称  数量         单价  \
# 0     2015-01-01 2015-01-13 2015-01-02   743    山地自行车  11  2039.9940
# 1     2015-01-01 2015-01-13 2015-01-06   745  山地自行车车架   3   722.5949
# 2     2015-01-01 2015-01-13 2015-01-03   709    公路自行车   5   874.7940
# 3     2015-01-01 2015-01-13 2015-01-08   709    公路自行车   2   419.4589
# 4     2015-01-01 2015-01-13 2015-01-08   743    山地自行车   1  2024.9940
# 5     2015-01-01 2015-01-13 2015-01-14   709    公路自行车  32  2146.9620
# 6     2015-01-01 2015-01-13 2015-01-12   731       帽子   2     5.1865
# 7     2015-01-01 2015-01-13 2015-01-03   759    长袖运动衫   2    28.8404
# 8     2015-01-01 2015-01-13 2015-01-05   709    公路自行车  11   874.7940
# 9     2015-01-01 2015-01-13 2015-01-08   709    公路自行车   9   419.4589
# 10    2015-01-01 2015-01-13 2015-01-10   743    山地自行车  20  2039.9940
# 11    2015-01-01 2015-01-13 2015-01-12   743    山地自行车  33  2039.9940
# 12    2015-01-01 2015-01-13 2015-01-14   758     运动头盔   1    20.1865
# 13    2015-01-01 2015-01-13 2015-01-15   759    长袖运动衫   1    28.8404
# 14    2015-01-01 2015-01-13 2015-01-14   709    公路自行车  16   874.7940
# 15    2015-01-01 2015-01-13 2015-01-02   743    山地自行车   3  2039.9940
# 16    2015-01-01 2015-01-13 2015-01-11   709    公路自行车  32  2146.9620
# 17    2015-01-01 2015-01-13 2015-01-03   731       帽子   3     5.1865
# 18    2015-01-01 2015-01-13 2015-01-13   709    公路自行车  29  2146.9620
# 19    2015-01-01 2015-01-13 2015-01-09   759    长袖运动衫   1    28.8404
# 20    2015-01-01 2015-01-13 2015-01-08   709    公路自行车   2   419.4589
# 21    2015-01-01 2015-01-13 2015-01-07   711  公路自行车车架   1   183.9382
# 22    2015-01-01 2015-01-13 2015-01-12   709    公路自行车  20  2146.9620
# 23    2015-01-01 2015-01-13 2015-01-03   711  公路自行车车架   2   183.9382
# 24    2015-01-01 2015-01-13 2015-01-08   709    公路自行车   3   874.7940
# 25    2015-01-01 2015-01-13 2015-01-16   743    山地自行车   4  2039.9940
# 26    2015-01-01 2015-01-13 2015-01-10   752  山地自行车袜子   2     5.7000
# 27    2015-01-01 2015-01-13 2015-01-12   709    公路自行车  29  2146.9620
# 28    2015-01-01 2015-01-13 2015-01-11   758     运动头盔   2    20.1865
# 29    2015-01-01 2015-01-13 2015-01-12   709    公路自行车  31  2146.9620
# ...          ...        ...        ...   ...      ...  ..        ...
# 15062 2016-02-29 2016-03-12 2016-03-15   709    公路自行车   8   874.7940
# 15063 2016-02-29 2016-03-12 2016-03-07   709    公路自行车  26  2146.9620
# 15064 2016-02-29 2016-03-12 2016-03-15   711  公路自行车车架   8   356.8980
# 15065 2016-02-29 2016-03-12 2016-03-05   709    公路自行车  34  2146.9620
# 15066 2016-02-29 2016-03-12 2016-03-06   711  公路自行车车架  18   758.0759
# 15067 2016-02-29 2016-03-12 2016-03-01   709    公路自行车   6   874.7940
# 15068 2016-02-29 2016-03-12 2016-03-06   759    长袖运动衫   1    28.8404
# 15069 2016-02-29 2016-03-12 2016-03-12   709    公路自行车  13   874.7940
# 15070 2016-02-29 2016-03-12 2016-03-12   731       帽子   2     5.1865
# 15071 2016-02-29 2016-03-12 2016-03-03   759    长袖运动衫   1    28.8404
# 15072 2016-02-29 2016-03-12 2016-03-14   709    公路自行车  50  2146.9620
# 15073 2016-02-29 2016-03-12 2016-03-08   711  公路自行车车架  13   356.8980
# 15074 2016-02-29 2016-03-12 2016-03-12   731       帽子   7     5.1865
# 15075 2016-02-29 2016-03-12 2016-03-02   758     运动头盔  14    20.1865
# 15076 2016-02-29 2016-03-12 2016-03-01   759    长袖运动衫  15    28.8404
# 15077 2016-02-29 2016-03-12 2016-03-09   731       帽子   1     5.1865
# 15078 2016-02-29 2016-03-12 2016-03-15   743    山地自行车  15  2039.9940
# 15079 2016-02-29 2016-03-12 2016-03-04   745  山地自行车车架   4   722.5949
# 15080 2016-02-29 2016-03-12 2016-03-13   752  山地自行车袜子   7     5.7000
# 15081 2016-02-29 2016-03-12 2016-03-14   731       帽子   3     5.1865
# 15082 2016-02-29 2016-03-12 2016-03-05   743    山地自行车  15  2039.9940
# 15083 2016-02-29 2016-03-12 2016-03-13   745  山地自行车车架   2   714.7043
# 15084 2016-02-29 2016-03-12 2016-03-09   752  山地自行车袜子   6     5.7000
# 15085 2016-02-29 2016-03-12 2016-03-03   758     运动头盔   6    20.1865
# 15086 2016-02-29 2016-03-12 2016-03-09   759    长袖运动衫   7    28.8404
# 15087 2016-02-29 2016-03-12 2016-03-14   709    公路自行车   1  3578.2700
# 15088 2016-02-29 2016-03-12 2016-03-06   709    公路自行车   1  3578.2700
# 15089 2016-02-29 2016-03-12 2016-03-10   709    公路自行车   1   699.0982
# 15090 2016-02-29 2016-03-12 2016-03-06   709    公路自行车   1  3578.2700
# 15091 2016-02-29 2016-03-12 2016-03-04   709    公路自行车   1   699.0982
#
#                 金额
# 0       22439.9340
# 1        2167.7847
# 2        4373.9700
# 3         838.9178
# 4        2024.9940
# 5       68702.7840
# 6          10.3730
# 7          57.6808
# 8        9622.7340
# 9        3775.1301
# 10      40799.8800
# 11      67319.8020
# 12         20.1865
# 13         28.8404
# 14      13996.7040
# 15       6119.9820
# 16      68702.7840
# 17         15.5595
# 18      62261.8980
# 19         28.8404
# 20        838.9178
# 21        183.9382
# 22      42939.2400
# 23        367.8764
# 24       2624.3820
# 25       8159.9760
# 26         11.4000
# 27      62261.8980
# 28         40.3730
# 29      66555.8220
# ...            ...
# 15062    6998.3520
# 15063   55821.0120
# 15064    2855.1840
# 15065   72996.7080
# 15066   13645.3662
# 15067    5248.7640
# 15068      28.8404
# 15069   11372.3220
# 15070      10.3730
# 15071      28.8404
# 15072  107348.1000
# 15073    4639.6740
# 15074      36.3055
# 15075     282.6110
# 15076     432.6060
# 15077       5.1865
# 15078   30599.9100
# 15079    2890.3796
# 15080      39.9000
# 15081      15.5595
# 15082   30599.9100
# 15083    1429.4086
# 15084      34.2000
# 15085     121.1190
# 15086     201.8828
# 15087    3578.2700
# 15088    3578.2700
# 15089     699.0982
# 15090    3578.2700
# 15091     699.0982
#
# [15092 rows x 14 columns]

# %%
# 对数据按时间排序,ascending=True表示升序排列
file_data = file_data.sort_values(by="销售时间", ascending=True)
file_data
# Out:
#           订单编号   客户ID               客户名称            客户编号 客户省份  销售代表ID  \
# 0      SO45266  29955   广东29955自行车销售有限公司  10-4020-000018   广东     212
# 131    SO45321  29522   辽宁29522自行车销售有限公司  10-4020-000312   辽宁     207
# 132    SO45321  29522   辽宁29522自行车销售有限公司  10-4020-000312   辽宁     207
# 133    SO45322  29866   辽宁29866自行车销售有限公司  10-4020-000256   辽宁     207
# 134    SO45323  29705   四川29705自行车销售有限公司  10-4020-000084   四川     214
# 135    SO45323  29705   四川29705自行车销售有限公司  10-4020-000084   四川     214
# 136    SO45323  29705   四川29705自行车销售有限公司  10-4020-000084   四川     214
# 137    SO45323  29705   四川29705自行车销售有限公司  10-4020-000084   四川     214
# 138    SO45323  29705   四川29705自行车销售有限公司  10-4020-000084   四川     214
# 139    SO45324  30012   西藏30012自行车销售有限公司  10-4020-000528   西藏     213
# 140    SO45325  30022  内蒙古30022自行车销售有限公司  10-4020-000313  内蒙古     208
# 141    SO45326  29906   安徽29906自行车销售有限公司  10-4020-000364   安徽     201
# 142    SO45327  29880   上海29880自行车销售有限公司  10-4020-000422   上海     202
# 143    SO45327  29880   上海29880自行车销售有限公司  10-4020-000422   上海     202
# 144    SO45328  29901   河北29901自行车销售有限公司  10-4020-000385   河北     208
# 145    SO45328  29901   河北29901自行车销售有限公司  10-4020-000385   河北     208
# 146    SO45328  29901   河北29901自行车销售有限公司  10-4020-000385   河北     208
# 147    SO45328  29901   河北29901自行车销售有限公司  10-4020-000385   河北     208
# 148    SO45329  29507   上海29507自行车销售有限公司  10-4020-000566   上海     202
# 149    SO45329  29507   上海29507自行车销售有限公司  10-4020-000566   上海     202
# 150    SO45329  29507   上海29507自行车销售有限公司  10-4020-000566   上海     202
# 151    SO45329  29507   上海29507自行车销售有限公司  10-4020-000566   上海     202
# 130    SO45321  29522   辽宁29522自行车销售有限公司  10-4020-000312   辽宁     207
# 129    SO45321  29522   辽宁29522自行车销售有限公司  10-4020-000312   辽宁     207
# 128    SO45320  30004   重庆30004自行车销售有限公司  10-4020-000559   重庆     214
# 127    SO45320  30004   重庆30004自行车销售有限公司  10-4020-000559   重庆     214
# 104    SO45311  29757   重庆29757自行车销售有限公司  10-4020-000492   重庆     214
# 105    SO45312  29493   四川29493自行车销售有限公司  10-4020-000548   四川     214
# 106    SO45312  29493   四川29493自行车销售有限公司  10-4020-000548   四川     214
# 107    SO45312  29493   四川29493自行车销售有限公司  10-4020-000548   四川     214
# ...        ...    ...                ...             ...  ...     ...
# 14904  SO63193  29517  黑龙江29517自行车销售有限公司  10-4020-000360  黑龙江     207
# 14934  SO63253  29990   云南29990自行车销售有限公司  10-4020-000214   云南     214
# 14932  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 14906  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 14907  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 14909  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 14910  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 14911  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 14912  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 14913  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 14914  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 14915  SO63240  30063   辽宁30063自行车销售有限公司  10-4020-000131   辽宁     207
# 14916  SO63240  30063   辽宁30063自行车销售有限公司  10-4020-000131   辽宁     207
# 14917  SO63240  30063   辽宁30063自行车销售有限公司  10-4020-000131   辽宁     207
# 14918  SO63240  30063   辽宁30063自行车销售有限公司  10-4020-000131   辽宁     207
# 14919  SO63240  30063   辽宁30063自行车销售有限公司  10-4020-000131   辽宁     207
# 14920  SO63240  30063   辽宁30063自行车销售有限公司  10-4020-000131   辽宁     207
# 14921  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 14922  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 14923  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 14924  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 14925  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 14926  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 14927  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 14928  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 14929  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 14930  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 14931  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 14933  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 14902  SO63188  29984   青海29984自行车销售有限公司  10-4020-000680   青海     213
#
#             销售时间     预计送货日期     实际送货日期  产品ID      产品名称  数量         单价  \
# 0     2015-01-01 2015-01-13 2015-01-02   743     山地自行车  11  2039.9940
# 131   2015-01-01 2015-01-13 2015-01-08   752   山地自行车袜子  19     5.2250
# 132   2015-01-01 2015-01-13 2015-01-10   759     长袖运动衫   5    28.8404
# 133   2015-01-01 2015-01-13 2015-01-14   709     公路自行车  26   874.7940
# 134   2015-01-01 2015-01-13 2015-01-09   709     公路自行车  59  2146.9620
# 135   2015-01-01 2015-01-13 2015-01-04   711   公路自行车车架  11   356.8980
# 136   2015-01-01 2015-01-13 2015-01-04   731        帽子  11     5.0136
# 137   2015-01-01 2015-01-13 2015-01-02   758      运动头盔  13    20.1865
# 138   2015-01-01 2015-01-13 2015-01-05   759     长袖运动衫  22    28.8404
# 139   2015-01-01 2015-01-13 2015-01-06   709     公路自行车   2   419.4589
# 140   2015-01-01 2015-01-13 2015-01-09   709     公路自行车   4   874.7940
# 141   2015-01-01 2015-01-13 2015-01-12   709     公路自行车  26  2146.9620
# 142   2015-01-01 2015-01-13 2015-01-03   743     山地自行车   6  2039.9940
# 143   2015-01-01 2015-01-13 2015-01-13   752   山地自行车袜子   2     5.7000
# 144   2015-01-01 2015-01-13 2015-01-09   731        帽子   5     5.1865
# 145   2015-01-01 2015-01-13 2015-01-10   743     山地自行车  31  2039.9940
# 146   2015-01-01 2015-01-13 2015-01-05   752   山地自行车袜子  10     5.7000
# 147   2015-01-01 2015-01-13 2015-01-14   759     长袖运动衫   5    28.8404
# 148   2015-01-01 2015-01-13 2015-01-10   731        帽子   4     5.1865
# 149   2015-01-01 2015-01-13 2015-01-13   743     山地自行车  28  2039.9940
# 150   2015-01-01 2015-01-13 2015-01-06   745   山地自行车车架   6   818.7000
# 151   2015-01-01 2015-01-13 2015-01-12   752   山地自行车袜子   1     5.7000
# 130   2015-01-01 2015-01-13 2015-01-02   743     山地自行车  30  2039.9940
# 129   2015-01-01 2015-01-13 2015-01-15   731        帽子   4     5.1865
# 128   2015-01-01 2015-01-13 2015-01-02   752   山地自行车袜子   4     5.7000
# 127   2015-01-01 2015-01-13 2015-01-06   743     山地自行车   5  2039.9940
# 104   2015-01-01 2015-01-13 2015-01-05   752   山地自行车袜子   2     5.7000
# 105   2015-01-01 2015-01-13 2015-01-13   709     公路自行车   1  2146.9620
# 106   2015-01-01 2015-01-13 2015-01-05   711   公路自行车车架   1   178.5808
# 107   2015-01-01 2015-01-13 2015-01-16   758      运动头盔   1    20.1865
# ...          ...        ...        ...   ...       ...  ..        ...
# 14904 2016-12-31 2017-01-12 2017-01-12   726   旅游自行车车架   2   200.0520
# 14934 2016-12-31 2017-01-12 2017-01-06   709     公路自行车   1   323.9940
# 14932 2016-12-31 2017-01-12 2017-01-03   758      运动头盔   7    20.9940
# 14906 2016-12-31 2017-01-12 2017-01-13   723        链条   2    12.1440
# 14907 2016-12-31 2017-01-12 2017-01-08   736    女士山地短裤   8    41.9940
# 14909 2016-12-31 2017-01-12 2017-01-06   741       前刹车   3    63.9000
# 14910 2016-12-31 2017-01-12 2017-01-01   743     山地自行车  10  1391.9940
# 14911 2016-12-31 2017-01-12 2017-01-01   744   山地自行车车把   4    26.7240
# 14912 2016-12-31 2017-01-12 2017-01-14   745   山地自行车车架  20   818.7000
# 14913 2016-12-31 2017-01-12 2017-01-05   746   山地自行车车座   3    23.4840
# 14914 2016-12-31 2017-01-12 2017-01-13   749  山地自行车脚踏板   1    48.5940
# 14915 2016-12-31 2017-01-12 2017-01-08   703       大齿盘   1   242.9940
# 14916 2016-12-31 2017-01-12 2017-01-07   704       底托架   3    72.8940
# 14917 2016-12-31 2017-01-12 2017-01-07   723        链条   2    12.1440
# 14918 2016-12-31 2017-01-12 2017-01-06   724     旅游自行车  29  1430.4420
# 14919 2016-12-31 2017-01-12 2017-01-15   739      前变速器   2    54.8940
# 14920 2016-12-31 2017-01-12 2017-01-12   741       前刹车   1    63.9000
# 14921 2016-12-31 2017-01-12 2017-01-03   702     车顶固定架   4    72.0000
# 14922 2016-12-31 2017-01-12 2017-01-08   706   短袖经典运动衫   6    32.3940
# 14923 2016-12-31 2017-01-12 2017-01-13   721      经典背心   8    38.1000
# 14924 2016-12-31 2017-01-12 2017-01-04   731        帽子   4     5.3940
# 14925 2016-12-31 2017-01-12 2017-01-13   736    女士山地短裤   9    41.9940
# 14926 2016-12-31 2017-01-12 2017-01-04   742       清洗剂   1     4.7700
# 14927 2016-12-31 2017-01-12 2017-01-01   743     山地自行车  45  1391.9940
# 14928 2016-12-31 2017-01-12 2017-01-04   744   山地自行车车把   1    37.1520
# 14929 2016-12-31 2017-01-12 2017-01-09   745   山地自行车车架   8   218.4540
# 14930 2016-12-31 2017-01-12 2017-01-01   749  山地自行车脚踏板   1    48.5940
# 14931 2016-12-31 2017-01-12 2017-01-12   755        水壶   5     2.9940
# 14933 2016-12-31 2017-01-12 2017-01-14   759     长袖运动衫   5    29.9940
# 14902 2016-12-31 2017-01-12 2017-01-15   743     山地自行车   2  1376.9940
#
#                 金额
# 0       22439.9340
# 131        99.2750
# 132       144.2020
# 133     22744.6440
# 134    126670.7580
# 135      3925.8780
# 136        55.1496
# 137       262.4245
# 138       634.4888
# 139       838.9178
# 140      3499.1760
# 141     55821.0120
# 142     12239.9640
# 143        11.4000
# 144        25.9325
# 145     63239.8140
# 146        57.0000
# 147       144.2020
# 148        20.7460
# 149     57119.8320
# 150      4912.2000
# 151         5.7000
# 130     61199.8200
# 129        20.7460
# 128        22.8000
# 127     10199.9700
# 104        11.4000
# 105      2146.9620
# 106       178.5808
# 107        20.1865
# ...            ...
# 14904     400.1040
# 14934     323.9940
# 14932     146.9580
# 14906      24.2880
# 14907     335.9520
# 14909     191.7000
# 14910   13919.9400
# 14911     106.8960
# 14912   16374.0000
# 14913      70.4520
# 14914      48.5940
# 14915     242.9940
# 14916     218.6820
# 14917      24.2880
# 14918   41482.8180
# 14919     109.7880
# 14920      63.9000
# 14921     288.0000
# 14922     194.3640
# 14923     304.8000
# 14924      21.5760
# 14925     377.9460
# 14926       4.7700
# 14927   62639.7300
# 14928      37.1520
# 14929    1747.6320
# 14930      48.5940
# 14931      14.9700
# 14933     149.9700
# 14902    2753.9880
#
# [15092 rows x 14 columns]

# %%
# 重置数据的索引
file_data = file_data.reset_index(drop=True)
print("文件预处理后的各项属性：")
show_data_basic_description(file_data)
# Out:
# 文件预处理后的各项属性：
# file_data文件的shape大小： (15092, 14)
# file_data文件的索引开头和末尾： RangeIndex(start=0, stop=15092, step=1)
# file_data文件的表头项： Index(['订单编号', '客户ID', '客户名称', '客户编号', '客户省份', '销售代表ID', '销售时间', '预计送货日期',
#        '实际送货日期', '产品ID', '产品名称', '数量', '单价', '金额'],
#       dtype='object')
# file_data文件的内容：
#        订单编号   客户ID              客户名称            客户编号 客户省份  销售代表ID       销售时间  \
# 0  SO45266  29955  广东29955自行车销售有限公司  10-4020-000018   广东     212 2015-01-01
# 1  SO45321  29522  辽宁29522自行车销售有限公司  10-4020-000312   辽宁     207 2015-01-01
# 2  SO45321  29522  辽宁29522自行车销售有限公司  10-4020-000312   辽宁     207 2015-01-01
# 3  SO45322  29866  辽宁29866自行车销售有限公司  10-4020-000256   辽宁     207 2015-01-01
# 4  SO45323  29705  四川29705自行车销售有限公司  10-4020-000084   四川     214 2015-01-01
#
#       预计送货日期     实际送货日期  产品ID     产品名称  数量         单价          金额
# 0 2015-01-13 2015-01-02   743    山地自行车  11  2039.9940   22439.934
# 1 2015-01-13 2015-01-08   752  山地自行车袜子  19     5.2250      99.275
# 2 2015-01-13 2015-01-10   759    长袖运动衫   5    28.8404     144.202
# 3 2015-01-13 2015-01-14   709    公路自行车  26   874.7940   22744.644
# 4 2015-01-13 2015-01-09   709    公路自行车  59  2146.9620  126670.758
# file_data文件的各项的数据类型：
#  订单编号              object
# 客户ID               int64
# 客户名称              object
# 客户编号              object
# 客户省份              object
# 销售代表ID             int64
# 销售时间      datetime64[ns]
# 预计送货日期    datetime64[ns]
# 实际送货日期    datetime64[ns]
# 产品ID               int64
# 产品名称              object
# 数量                 int64
# 单价               float64
# 金额               float64
# dtype: object

# %%
# 计算自行车的种类和自行车的总销售数量
def compute_commodity_type_and_sum(fl_data):
   # 去除重复的自行车种类
   no_duplicate_file_data = fl_data.drop_duplicates(subset=["产品ID"])
   # 计算自行车的种类
   fl_data_total_consumption_type = no_duplicate_file_data.shape[0]
   # 计算自行车的总销售数量
   fl_data = fl_data.dropna(subset=["产品ID"], how="any")
   fl_data_total_sum = fl_data.loc[:, "数量"].sum()
   return fl_data_total_consumption_type, fl_data_total_sum

# %%
file_data_total_consumption_type, file_data_total_sum = compute_commodity_type_and_sum(file_data)
print("销售自行车的种类:{} 销售自行车的数量:{}".format(file_data_total_consumption_type, int(file_data_total_sum)))
# Out:
# 销售自行车的种类:59 销售自行车的数量:100155

# %%
# 计算总销售次数，月份数，月均销售次数，月均销售次数 = 总销售次数 / 月份数
def compute_consumption_num(fl_data):
   # 先删除重复的数据,因为一个人一次消费可能买好几种自行车
   no_duplicate_file_data = fl_data.drop_duplicates(subset=["销售时间", "客户ID"])
   # 计算总销售次数
   fl_data_total_consumption_num = no_duplicate_file_data.shape[0]
   # 计算月份数
   # 先给上面删除了重复数据的文件排序，重新组织索引
   no_duplicate_file_data = no_duplicate_file_data.sort_values(by="销售时间", ascending=True)
   no_duplicate_file_data = no_duplicate_file_data.reset_index(drop=True)
   # 最早购买时间，最晚购买时间，计算天数和月份数
   start_time = no_duplicate_file_data.loc[0, "销售时间"]
   end_time = no_duplicate_file_data.loc[fl_data_total_consumption_num - 1, "销售时间"]
   fl_data_days_count = (end_time - start_time).days
   # //表示除以后返回商的整数部分
   fl_data_months_count = fl_data_days_count // 30
   # 计算月均销售次数，用总销售次数除以月数
   fl_data_per_month_average_consumption_num = fl_data_total_consumption_num / fl_data_months_count
   return fl_data_total_consumption_num, fl_data_months_count, fl_data_per_month_average_consumption_num

# %%
total_consumption_num, months_count, per_month_average_consumption_num = compute_consumption_num(file_data)
print("总销售次数为:{} 月份数为:{} 月均销售次数为:{:.1f}".format(total_consumption_num, months_count, per_month_average_consumption_num))
# Out:
# 总销售次数为:6554 月份数为:24 月均销售次数为:273.1

# %%
#计算总销售金额，平均每月销售金额，平均每单销售金额
def compute_consumption_money(fl_data, ttl_consumption_num, mth_count):
   # 计算月均销售金额，先计算总销售金额，再除以月数
   fl_data_total_consumption_money = fl_data.loc[:, "金额"].sum()
   fl_data_per_month_consumption_money = fl_data_total_consumption_money / mth_count
   # 计算平均每单销售金额，用总销售金额除以总销售次数
   fl_data_per_sale_consumption_money = fl_data_total_consumption_money / ttl_consumption_num
   return fl_data_total_consumption_money, fl_data_per_month_consumption_money, fl_data_per_sale_consumption_money

# %%
total_consumption_money, per_month_consumption_money, per_sale_consumption_money = compute_consumption_money(file_data,
                                                                                                             total_consumption_num,
                                                                                                             months_count)
print("总销售金额为:{:.2f} 月均销售金额为:{:.2f} 平均每单销售金额为:{:.2f}".format(total_consumption_money, per_month_consumption_money,
                                                             per_sale_consumption_money))
# Out:
# 总销售金额为:70299898.66 月均销售金额为:2929162.44 平均每单销售金额为:10726.26

# %%
# 最大和最小销售金额的对应的日期
def max_and_min_consumption_money_day(fl_data):
   fl_data_money = fl_data[['销售时间', '金额']]
   fl_data_money.index = fl_data_money['销售时间']
   fl_data_money_group_day = fl_data_money.groupby(fl_data_money.index)
   fl_data_money_group_day = fl_data_money_group_day.sum()
   # 按求最大销售金额和最小销售金额及对应的日期
   fl_data_money_group_day = fl_data_money_group_day.sort_values(by='金额', ascending=False)
   max_money_fl_data_group_day = fl_data_money_group_day.iloc[0:1, :]
   fl_data_money_group_day = fl_data_money_group_day.sort_values(by='金额', ascending=True)
   min_money_fl_data_group_day = fl_data_money_group_day.iloc[0:1, :]
   return max_money_fl_data_group_day, min_money_fl_data_group_day

# %%
max_sum_group_day, min_sum_group_day = max_and_min_consumption_money_day(file_data)
print("最大每日销售金额及对应的日期：\n", max_sum_group_day)
print("最小每日销售金额及对应的日期：\n", min_sum_group_day)
# Out:
# 最大每日销售金额及对应的日期：
#                        金额
# 销售时间
# 2015-06-30  5.953467e+06
# 最小每日销售金额及对应的日期：
#                 金额
# 销售时间
# 2016-07-13  11.27

# %%
# 最大和最小销售数量的对应的日期
def max_and_min_consumption_sum_day(fl_data):
   fl_data_sum = fl_data[['销售时间', '数量']]
   fl_data_sum.index = fl_data_sum['销售时间']
   fl_data_sum_group_day = fl_data_sum.groupby(fl_data_sum.index)
   fl_data_sum_group_day = fl_data_sum_group_day.sum()
   # 按求最大销售金额和最小销售金额及对应的日期
   fl_data_sum_group_day = fl_data_sum_group_day.sort_values(by='数量', ascending=False)
   max_sum_fl_data_group_day = fl_data_sum_group_day.iloc[0:1, :]
   fl_data_sum_group_day = fl_data_sum_group_day.sort_values(by='数量', ascending=True)
   min_sum_fl_data_group_day = fl_data_sum_group_day.iloc[0:1, :]
   return max_sum_fl_data_group_day, min_sum_fl_data_group_day

# %%
max_sum_group_day, min_sum_group_day = max_and_min_consumption_sum_day(file_data)
print("最大每日销售数量及对应的日期：\n", max_sum_group_day)
print("最小每日销售数量及对应的日期：\n", min_sum_group_day)
# Out:
# 最大每日销售数量及对应的日期：
#                 数量
# 销售时间
# 2015-06-30  11053
# 最小每日销售数量及对应的日期：
#              数量
# 销售时间
# 2016-05-22   1

# %%
# 在使用matplotlib画图时使用的数据是file_data的copy，防止画图时影响file_data的数据
file_data_copy = file_data.copy()

# %%
# 对文件数据按时间升序排序，并在排序后重置索引
def sort_data_value_as_time(fl_data):
   # 对数据按时间排序,ascending=True表示升序排列
   fl_data = fl_data.sort_values(by="销售时间", ascending=True)
   # 重置数据的索引,重置后索引变成按时间排序后的索引了
   fl_data = fl_data.reset_index(drop=True)
   return fl_data
file_data_copy
# Out:
#           订单编号   客户ID               客户名称            客户编号 客户省份  销售代表ID  \
# 0      SO45266  29955   广东29955自行车销售有限公司  10-4020-000018   广东     212
# 1      SO45321  29522   辽宁29522自行车销售有限公司  10-4020-000312   辽宁     207
# 2      SO45321  29522   辽宁29522自行车销售有限公司  10-4020-000312   辽宁     207
# 3      SO45322  29866   辽宁29866自行车销售有限公司  10-4020-000256   辽宁     207
# 4      SO45323  29705   四川29705自行车销售有限公司  10-4020-000084   四川     214
# 5      SO45323  29705   四川29705自行车销售有限公司  10-4020-000084   四川     214
# 6      SO45323  29705   四川29705自行车销售有限公司  10-4020-000084   四川     214
# 7      SO45323  29705   四川29705自行车销售有限公司  10-4020-000084   四川     214
# 8      SO45323  29705   四川29705自行车销售有限公司  10-4020-000084   四川     214
# 9      SO45324  30012   西藏30012自行车销售有限公司  10-4020-000528   西藏     213
# 10     SO45325  30022  内蒙古30022自行车销售有限公司  10-4020-000313  内蒙古     208
# 11     SO45326  29906   安徽29906自行车销售有限公司  10-4020-000364   安徽     201
# 12     SO45327  29880   上海29880自行车销售有限公司  10-4020-000422   上海     202
# 13     SO45327  29880   上海29880自行车销售有限公司  10-4020-000422   上海     202
# 14     SO45328  29901   河北29901自行车销售有限公司  10-4020-000385   河北     208
# 15     SO45328  29901   河北29901自行车销售有限公司  10-4020-000385   河北     208
# 16     SO45328  29901   河北29901自行车销售有限公司  10-4020-000385   河北     208
# 17     SO45328  29901   河北29901自行车销售有限公司  10-4020-000385   河北     208
# 18     SO45329  29507   上海29507自行车销售有限公司  10-4020-000566   上海     202
# 19     SO45329  29507   上海29507自行车销售有限公司  10-4020-000566   上海     202
# 20     SO45329  29507   上海29507自行车销售有限公司  10-4020-000566   上海     202
# 21     SO45329  29507   上海29507自行车销售有限公司  10-4020-000566   上海     202
# 22     SO45321  29522   辽宁29522自行车销售有限公司  10-4020-000312   辽宁     207
# 23     SO45321  29522   辽宁29522自行车销售有限公司  10-4020-000312   辽宁     207
# 24     SO45320  30004   重庆30004自行车销售有限公司  10-4020-000559   重庆     214
# 25     SO45320  30004   重庆30004自行车销售有限公司  10-4020-000559   重庆     214
# 26     SO45311  29757   重庆29757自行车销售有限公司  10-4020-000492   重庆     214
# 27     SO45312  29493   四川29493自行车销售有限公司  10-4020-000548   四川     214
# 28     SO45312  29493   四川29493自行车销售有限公司  10-4020-000548   四川     214
# 29     SO45312  29493   四川29493自行车销售有限公司  10-4020-000548   四川     214
# ...        ...    ...                ...             ...  ...     ...
# 15062  SO63193  29517  黑龙江29517自行车销售有限公司  10-4020-000360  黑龙江     207
# 15063  SO63253  29990   云南29990自行车销售有限公司  10-4020-000214   云南     214
# 15064  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 15065  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 15066  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 15067  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 15068  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 15069  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 15070  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 15071  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 15072  SO63209  30101   陕西30101自行车销售有限公司  10-4020-000632   陕西     213
# 15073  SO63240  30063   辽宁30063自行车销售有限公司  10-4020-000131   辽宁     207
# 15074  SO63240  30063   辽宁30063自行车销售有限公司  10-4020-000131   辽宁     207
# 15075  SO63240  30063   辽宁30063自行车销售有限公司  10-4020-000131   辽宁     207
# 15076  SO63240  30063   辽宁30063自行车销售有限公司  10-4020-000131   辽宁     207
# 15077  SO63240  30063   辽宁30063自行车销售有限公司  10-4020-000131   辽宁     207
# 15078  SO63240  30063   辽宁30063自行车销售有限公司  10-4020-000131   辽宁     207
# 15079  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 15080  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 15081  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 15082  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 15083  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 15084  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 15085  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 15086  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 15087  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 15088  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 15089  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 15090  SO63252  29523   湖北29523自行车销售有限公司  10-4020-000309   湖北     203
# 15091  SO63188  29984   青海29984自行车销售有限公司  10-4020-000680   青海     213
#
#             销售时间     预计送货日期     实际送货日期  产品ID      产品名称  数量         单价  \
# 0     2015-01-01 2015-01-13 2015-01-02   743     山地自行车  11  2039.9940
# 1     2015-01-01 2015-01-13 2015-01-08   752   山地自行车袜子  19     5.2250
# 2     2015-01-01 2015-01-13 2015-01-10   759     长袖运动衫   5    28.8404
# 3     2015-01-01 2015-01-13 2015-01-14   709     公路自行车  26   874.7940
# 4     2015-01-01 2015-01-13 2015-01-09   709     公路自行车  59  2146.9620
# 5     2015-01-01 2015-01-13 2015-01-04   711   公路自行车车架  11   356.8980
# 6     2015-01-01 2015-01-13 2015-01-04   731        帽子  11     5.0136
# 7     2015-01-01 2015-01-13 2015-01-02   758      运动头盔  13    20.1865
# 8     2015-01-01 2015-01-13 2015-01-05   759     长袖运动衫  22    28.8404
# 9     2015-01-01 2015-01-13 2015-01-06   709     公路自行车   2   419.4589
# 10    2015-01-01 2015-01-13 2015-01-09   709     公路自行车   4   874.7940
# 11    2015-01-01 2015-01-13 2015-01-12   709     公路自行车  26  2146.9620
# 12    2015-01-01 2015-01-13 2015-01-03   743     山地自行车   6  2039.9940
# 13    2015-01-01 2015-01-13 2015-01-13   752   山地自行车袜子   2     5.7000
# 14    2015-01-01 2015-01-13 2015-01-09   731        帽子   5     5.1865
# 15    2015-01-01 2015-01-13 2015-01-10   743     山地自行车  31  2039.9940
# 16    2015-01-01 2015-01-13 2015-01-05   752   山地自行车袜子  10     5.7000
# 17    2015-01-01 2015-01-13 2015-01-14   759     长袖运动衫   5    28.8404
# 18    2015-01-01 2015-01-13 2015-01-10   731        帽子   4     5.1865
# 19    2015-01-01 2015-01-13 2015-01-13   743     山地自行车  28  2039.9940
# 20    2015-01-01 2015-01-13 2015-01-06   745   山地自行车车架   6   818.7000
# 21    2015-01-01 2015-01-13 2015-01-12   752   山地自行车袜子   1     5.7000
# 22    2015-01-01 2015-01-13 2015-01-02   743     山地自行车  30  2039.9940
# 23    2015-01-01 2015-01-13 2015-01-15   731        帽子   4     5.1865
# 24    2015-01-01 2015-01-13 2015-01-02   752   山地自行车袜子   4     5.7000
# 25    2015-01-01 2015-01-13 2015-01-06   743     山地自行车   5  2039.9940
# 26    2015-01-01 2015-01-13 2015-01-05   752   山地自行车袜子   2     5.7000
# 27    2015-01-01 2015-01-13 2015-01-13   709     公路自行车   1  2146.9620
# 28    2015-01-01 2015-01-13 2015-01-05   711   公路自行车车架   1   178.5808
# 29    2015-01-01 2015-01-13 2015-01-16   758      运动头盔   1    20.1865
# ...          ...        ...        ...   ...       ...  ..        ...
# 15062 2016-12-31 2017-01-12 2017-01-12   726   旅游自行车车架   2   200.0520
# 15063 2016-12-31 2017-01-12 2017-01-06   709     公路自行车   1   323.9940
# 15064 2016-12-31 2017-01-12 2017-01-03   758      运动头盔   7    20.9940
# 15065 2016-12-31 2017-01-12 2017-01-13   723        链条   2    12.1440
# 15066 2016-12-31 2017-01-12 2017-01-08   736    女士山地短裤   8    41.9940
# 15067 2016-12-31 2017-01-12 2017-01-06   741       前刹车   3    63.9000
# 15068 2016-12-31 2017-01-12 2017-01-01   743     山地自行车  10  1391.9940
# 15069 2016-12-31 2017-01-12 2017-01-01   744   山地自行车车把   4    26.7240
# 15070 2016-12-31 2017-01-12 2017-01-14   745   山地自行车车架  20   818.7000
# 15071 2016-12-31 2017-01-12 2017-01-05   746   山地自行车车座   3    23.4840
# 15072 2016-12-31 2017-01-12 2017-01-13   749  山地自行车脚踏板   1    48.5940
# 15073 2016-12-31 2017-01-12 2017-01-08   703       大齿盘   1   242.9940
# 15074 2016-12-31 2017-01-12 2017-01-07   704       底托架   3    72.8940
# 15075 2016-12-31 2017-01-12 2017-01-07   723        链条   2    12.1440
# 15076 2016-12-31 2017-01-12 2017-01-06   724     旅游自行车  29  1430.4420
# 15077 2016-12-31 2017-01-12 2017-01-15   739      前变速器   2    54.8940
# 15078 2016-12-31 2017-01-12 2017-01-12   741       前刹车   1    63.9000
# 15079 2016-12-31 2017-01-12 2017-01-03   702     车顶固定架   4    72.0000
# 15080 2016-12-31 2017-01-12 2017-01-08   706   短袖经典运动衫   6    32.3940
# 15081 2016-12-31 2017-01-12 2017-01-13   721      经典背心   8    38.1000
# 15082 2016-12-31 2017-01-12 2017-01-04   731        帽子   4     5.3940
# 15083 2016-12-31 2017-01-12 2017-01-13   736    女士山地短裤   9    41.9940
# 15084 2016-12-31 2017-01-12 2017-01-04   742       清洗剂   1     4.7700
# 15085 2016-12-31 2017-01-12 2017-01-01   743     山地自行车  45  1391.9940
# 15086 2016-12-31 2017-01-12 2017-01-04   744   山地自行车车把   1    37.1520
# 15087 2016-12-31 2017-01-12 2017-01-09   745   山地自行车车架   8   218.4540
# 15088 2016-12-31 2017-01-12 2017-01-01   749  山地自行车脚踏板   1    48.5940
# 15089 2016-12-31 2017-01-12 2017-01-12   755        水壶   5     2.9940
# 15090 2016-12-31 2017-01-12 2017-01-14   759     长袖运动衫   5    29.9940
# 15091 2016-12-31 2017-01-12 2017-01-15   743     山地自行车   2  1376.9940
#
#                 金额
# 0       22439.9340
# 1          99.2750
# 2         144.2020
# 3       22744.6440
# 4      126670.7580
# 5        3925.8780
# 6          55.1496
# 7         262.4245
# 8         634.4888
# 9         838.9178
# 10       3499.1760
# 11      55821.0120
# 12      12239.9640
# 13         11.4000
# 14         25.9325
# 15      63239.8140
# 16         57.0000
# 17        144.2020
# 18         20.7460
# 19      57119.8320
# 20       4912.2000
# 21          5.7000
# 22      61199.8200
# 23         20.7460
# 24         22.8000
# 25      10199.9700
# 26         11.4000
# 27       2146.9620
# 28        178.5808
# 29         20.1865
# ...            ...
# 15062     400.1040
# 15063     323.9940
# 15064     146.9580
# 15065      24.2880
# 15066     335.9520
# 15067     191.7000
# 15068   13919.9400
# 15069     106.8960
# 15070   16374.0000
# 15071      70.4520
# 15072      48.5940
# 15073     242.9940
# 15074     218.6820
# 15075      24.2880
# 15076   41482.8180
# 15077     109.7880
# 15078      63.9000
# 15079     288.0000
# 15080     194.3640
# 15081     304.8000
# 15082      21.5760
# 15083     377.9460
# 15084       4.7700
# 15085   62639.7300
# 15086      37.1520
# 15087    1747.6320
# 15088      48.5940
# 15089      14.9700
# 15090     149.9700
# 15091    2753.9880
#
# [15092 rows x 14 columns]

# %%
# 画各个月单独的每日销售金额直方图
def draw_and_save_per_day_per_month_consumption_bar(fl_data):
   # 对文件数据按时间升序排序，并在排序后重置索引
   fl_data = sort_data_value_as_time(fl_data)
   # 如果图片保存路径不存在则创建
   if not os.path.exists("./count_image/"):
      os.mkdir("./count_image")
   fl_data_money = fl_data[['销售时间', '金额']]
   fl_data_money.index = fl_data_money['销售时间']
   # 画图
   for index in range(1, 13, 1):
      month_index = "2015-" + str(index)
      per_mont_fl_data_money = fl_data_money[month_index]
      per_mont_fl_data_money_day_group = per_mont_fl_data_money.groupby(per_mont_fl_data_money.index.day)
      per_mont_fl_data_money_day_group = per_mont_fl_data_money_day_group.sum()
      per_mont_fl_data_money_day_group.plot(figsize=(12, 8), kind='bar')
      image_title = str(index) + "月每日销售金额直方图"
      plt.title(image_title)
      plt.xlabel('销售时间')
      plt.ylabel('金额')
      save_path = "./count_image/per_day_consumption_month_" +str(index) + "_bar_2015年.jpg"
      plt.savefig(save_path)
      plt.close()

# %%
draw_and_save_per_day_per_month_consumption_bar(file_data_copy)

# %%
# 画各个月单独的每日销售金额直方图
def draw_and_save_per_day_per_month_consumption_bar(fl_data):
   # 对文件数据按时间升序排序，并在排序后重置索引
   fl_data = sort_data_value_as_time(fl_data)
   # 如果图片保存路径不存在则创建
   if not os.path.exists("./count_image/"):
      os.mkdir("./count_image")
   fl_data_money = fl_data[['销售时间', '金额']]
   fl_data_money.index = fl_data_money['销售时间']
   # 画图
   for index in range(1, 13, 1):
      month_index = "2016-" + str(index)
      per_mont_fl_data_money = fl_data_money[month_index]
      per_mont_fl_data_money_day_group = per_mont_fl_data_money.groupby(per_mont_fl_data_money.index.day)
      per_mont_fl_data_money_day_group = per_mont_fl_data_money_day_group.sum()
      per_mont_fl_data_money_day_group.plot(figsize=(12, 8), kind='bar')
      image_title = str(index) + "月每日销售金额直方图"
      plt.title(image_title)
      plt.xlabel('销售时间')
      plt.ylabel('金额')
      save_path = "./count_image/per_day_consumption_month_" +str(index) + "_bar_2016年.jpg"
      plt.savefig(save_path)
      plt.close()

# %%
draw_and_save_per_day_per_month_consumption_bar(file_data_copy)

# %%
# 画出按月份的销售金额直方图
def draw_and_save_per_month_consumption_bar(fl_data):
    # 对文件数据按时间升序排序，并在排序后重置索引
    fl_data = sort_data_value_as_time(fl_data)
    # 如果图片保存路径不存在则创建
    if not os.path.exists("./count_image/"):
        os.mkdir("./count_image")
    fl_data_money = fl_data[['销售时间', '金额']]
    fl_data_money.index = fl_data_money['销售时间']
    # 如果图片保存路径不存在则创建
    for year_index in ['2015','2016']:
        per_year_fl_data_money = fl_data_money[year_index]
        fl_data_money_month_group = per_year_fl_data_money.groupby(per_year_fl_data_money.index.month)
        fl_data_money_month_group_count = fl_data_money_month_group.sum()
        fl_data_money_month_group_count.plot(figsize=(12, 8), kind='bar')
        plt.title('每月销售金额直方图')
        plt.xlabel('月份')
        plt.ylabel('销售金额')
        plt.legend(loc="best")
        plt.savefig("./count_image/per_month_consumption_bar_"+year_index+".jpg")
        plt.close()

# %%
draw_and_save_per_month_consumption_bar(file_data_copy)

# %%
# 画出按年的销售金额直方图
def draw_and_save_per_year_consumption_bar(fl_data):
    # 对文件数据按时间升序排序，并在排序后重置索引
    fl_data = sort_data_value_as_time(fl_data)
    # 如果图片保存路径不存在则创建
    if not os.path.exists("./count_image/"):
        os.mkdir("./count_image")
    fl_data_money = fl_data[['销售时间', '金额']]
    fl_data_money.index = fl_data_money['销售时间']
    # 如果图片保存路径不存在则创建
    per_year_fl_data_money=fl_data_money
    fl_data_money_year_group = per_year_fl_data_money.groupby(per_year_fl_data_money.index.year)
    fl_data_money_year_group_count = fl_data_money_year_group.sum()
    fl_data_money_year_group_count.plot(figsize=(12, 8), kind='bar')
    plt.title('每年销售金额直方图')
    plt.xlabel('年份')
    plt.ylabel('销售金额')
    plt.legend(loc="best")
    plt.savefig("./count_image/per_year_consumption_bar.jpg")
    plt.close()

# %%
draw_and_save_per_year_consumption_bar(file_data_copy)

# %%
# 画出按月份的销售金额变化直线图
def draw_and_save_per_month_consumption_line(fl_data):
    # 将销售时间聚合按月分组
    fl_data_money = fl_data[['销售时间', '金额']]
    fl_data_money.index = fl_data_money['销售时间']
    # 如果图片保存路径不存在则创建
    for year_index in ['2015','2016']:
        per_year_fl_data_money = fl_data_money[year_index]
        fl_data_month_group = fl_data.groupby( fl_data_money.index.month)
        months_consumption_count = fl_data_month_group.sum()
        # 画出按月份的销售金额变化直方图
        plt.figure(figsize=(12, 8))
        plt.plot(months_consumption_count['金额'])
        plt.title('每月销售金额变化图')
        plt.ylabel('金额')
        plt.savefig("./count_image/per_month_consumption_line_"+year_index+".jpg")
        plt.close()

# %%
draw_and_save_per_month_consumption_line(file_data_copy)

# %%
# 画出销量前十和最后十名的自行车的直方图
def draw_and_save_first_ten_medicine_bar(fl_data):
    # 统计各种自行车的销售数量
    medicine_data = fl_data[['产品名称', '数量']]
    medicine_data_group = medicine_data.groupby('产品名称')[['数量']]
    medicine_data_group_count = medicine_data_group.sum()
    # 对统计的每种自行车销售数量进行降序排序
    medicine_data_group_count = medicine_data_group_count.sort_values(by='数量', ascending=False)
    # 截取销售数量最多和最少的十种自行车
    top_ten_medicine = medicine_data_group_count.iloc[0:10, :]
    under_ten_medicine = medicine_data_group_count.iloc[-11:-1, :]
    # 最后十名升序排序
    under_ten_medicine = under_ten_medicine.sort_values(by="数量", ascending=True)
    # 画图，kind='bar'表示用条形图
    top_ten_medicine.plot(figsize=(12, 8), kind='bar')
    plt.title('前十名销量的自行车')
    plt.xlabel('自行车种类')
    plt.ylabel('数量')
    plt.legend(loc="best")
    plt.savefig("./count_image/top_ten_medicine_sale_graph.jpg")
    plt.close()
    
    under_ten_medicine.plot(figsize=(12, 8), kind='bar')
    plt.title('最后十名销量的自行车')
    plt.xlabel('自行车种类')
    plt.ylabel('销售数量')
    plt.legend(loc="best")
    plt.savefig("./count_image/under_ten_medicine_sale_graph.jpg")
    plt.close()

# %%
draw_and_save_first_ten_medicine_bar(file_data_copy)
